# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv(r"college_student_placement_dataset.csv")

# %%
df.sample(5)
# Out:
#      College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 8394    CLG0022   87             6.39  6.32                     4
# 2677    CLG0064   76             9.17  8.96                     8
# 923     CLG0001   89             7.11  7.31                     8
# 2133    CLG0098  108             9.05  9.48                     8
# 7389    CLG0010  112             5.72  5.27                     5
#
#      Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 8394                    No                       1                     4
# 2677                   Yes                      10                     1
# 923                     No                       5                     1
# 2133                   Yes                       0                     2
# 7389                    No                       0                     5
#
#       Projects_Completed Placement
# 8394                   2        No
# 2677                   0        No
# ...

# %%
df.columns
# Out:
# Index(['College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed', 'Placement'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   College_ID              10000 non-null  object
#  1   IQ                      10000 non-null  int64
#  2   Prev_Sem_Result         10000 non-null  float64
#  3   CGPA                    10000 non-null  float64
#  4   Academic_Performance    10000 non-null  int64
#  5   Internship_Experience   10000 non-null  object
#  6   Extra_Curricular_Score  10000 non-null  int64
#  7   Communication_Skills    10000 non-null  int64
#  8   Projects_Completed      10000 non-null  int64
#  9   Placement               10000 non-null  object
# dtypes: float64(2), int64(5), object(3)
# memory usage: 781.4+ KB

# %%
df=df.drop(columns="College_ID")

# %%
df
# Out:
#        IQ  Prev_Sem_Result  CGPA  Academic_Performance Internship_Experience  \
# 0     107             6.61  6.28                     8                    No
# 1      97             5.52  5.37                     8                    No
# 2     109             5.36  5.83                     9                    No
# 3     122             5.47  5.75                     6                   Yes
# 4      96             7.91  7.69                     7                    No
# ...   ...              ...   ...                   ...                   ...
# 9995  119             8.41  8.29                     4                    No
# 9996   70             9.25  9.34                     7                    No
# 9997   89             6.08  6.25                     3                   Yes
# 9998  107             8.77  8.92                     3                    No
# 9999  109             9.41  9.77                     8                    No
#
# ...

# %%
input_vars=df.iloc[:,:-1]

# %%
input_vars
# Out:
#        IQ  Prev_Sem_Result  CGPA  Academic_Performance Internship_Experience  \
# 0     107             6.61  6.28                     8                    No
# 1      97             5.52  5.37                     8                    No
# 2     109             5.36  5.83                     9                    No
# 3     122             5.47  5.75                     6                   Yes
# 4      96             7.91  7.69                     7                    No
# ...   ...              ...   ...                   ...                   ...
# 9995  119             8.41  8.29                     4                    No
# 9996   70             9.25  9.34                     7                    No
# 9997   89             6.08  6.25                     3                   Yes
# 9998  107             8.77  8.92                     3                    No
# 9999  109             9.41  9.77                     8                    No
#
# ...

# %%
df.isnull().value_counts()
# Out:
# IQ     Prev_Sem_Result  CGPA   Academic_Performance  Internship_Experience  Extra_Curricular_Score  Communication_Skills  Projects_Completed  Placement
# False  False            False  False                 False                  False                   False                 False               False        10000
# Name: count, dtype: int64

# %% [markdown]
# so there are no null values

# %% [markdown]
# # now we build  a transformer :

# %%
from sklearn.compose import ColumnTransformer

# %%
input_vars.iloc[0]
# Out:
# IQ                         107
# Prev_Sem_Result           6.61
# CGPA                      6.28
# Academic_Performance         8
# Internship_Experience       No
# Extra_Curricular_Score       8
# Communication_Skills         8
# Projects_Completed           4
# Name: 0, dtype: object

# %% [markdown]
# # we will apply :
# 1) onehot-->Internship_Experience
# 2) ordinal-->
# 3) standardscaler--> iq ,prev_sem, acadamic prformance, project_completed,commu_skills,

# %%
one_hot_list=["Internship_Experience"]
standard_s_list = input_vars.drop(columns="Internship_Experience").columns
type(one_hot_list)
# Out:
# list

# %%
standard_s_list=list(standard_s_list)

# %%
input_vars.columns
# Out:
# Index(['IQ', 'Prev_Sem_Result', 'CGPA', 'Academic_Performance',
#        'Internship_Experience', 'Extra_Curricular_Score',
#        'Communication_Skills', 'Projects_Completed'],
#       dtype='object')

# %%
df["Internship_Experience"].value_counts()
# Out:
# Internship_Experience
# No     6036
# Yes    3964
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler

# %%
preprocessor=ColumnTransformer(
    transformers=[
    ("tf1",OneHotEncoder(categories=[["No","Yes"]]),one_hot_list),
    ("tf2",StandardScaler(),standard_s_list) ],
    remainder="passthrough"

)

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

# %%
model_pipeline=Pipeline(
    steps=[
        ("preprocessor",preprocessor),
        ("model",LogisticRegression(max_iter=1000, class_weight='balanced'))
    ]
)

# %%
from sklearn.model_selection import train_test_split

# %%
x=input_vars

# %%
x
# Out:
#        IQ  Prev_Sem_Result  CGPA  Academic_Performance Internship_Experience  \
# 0     107             6.61  6.28                     8                    No
# 1      97             5.52  5.37                     8                    No
# 2     109             5.36  5.83                     9                    No
# 3     122             5.47  5.75                     6                   Yes
# 4      96             7.91  7.69                     7                    No
# ...   ...              ...   ...                   ...                   ...
# 9995  119             8.41  8.29                     4                    No
# 9996   70             9.25  9.34                     7                    No
# 9997   89             6.08  6.25                     3                   Yes
# 9998  107             8.77  8.92                     3                    No
# 9999  109             9.41  9.77                     8                    No
#
# ...

# %%
y=df["Placement"]

# %%
y
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 9995    Yes
# 9996     No
# 9997     No
# 9998     No
# 9999     No
# Name: Placement, Length: 10000, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=4,stratify=y)

# %%
x_train
# Out:
#        IQ  Prev_Sem_Result  CGPA  Academic_Performance Internship_Experience  \
# 2350  115             5.96  6.34                     8                   Yes
# 9555  130             8.16  7.89                     5                   Yes
# 8388   91             9.80  9.60                     3                    No
# 5830   96             5.65  5.30                     7                   Yes
# 5116  125             6.18  6.28                     4                    No
# ...   ...              ...   ...                   ...                   ...
# 4439  107             9.56  9.71                     6                    No
# 3972  105             8.24  8.24                     6                   Yes
# 1992  117             9.21  9.29                     8                    No
# 3423  106             7.98  8.26                     2                    No
# 6581  103             8.06  8.19                     4                    No
#
# ...

# %%
y_train
# Out:
# 2350     No
# 9555     No
# 8388     No
# 5830     No
# 5116     No
#        ...
# 4439     No
# 3972    Yes
# 1992    Yes
# 3423     No
# 6581     No
# Name: Placement, Length: 7500, dtype: object

# %%
model_pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('tf1',
#                                                   OneHotEncoder(categories=[['No',
#                                                                              'Yes']]),
#                                                   ['Internship_Experience']),
#                                                  ('tf2', StandardScaler(),
#                                                   ['IQ', 'Prev_Sem_Result',
#                                                    'CGPA',
#                                                    'Academic_Performance',
#                                                    'Extra_Curricular_Score',
#                                                    'Communication_Skills',
#                                                    'Projects_Completed'])])),
#                 ('model',
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
result_train= model_pipeline.predict(x_train)
result_test= model_pipeline.predict(x_test)

# %%
acc_train=accuracy_score(result_train,y_train)*100
acc_test=accuracy_score(result_test,y_test)*100

# %%
print(f"the model accuracy from tarining data is {acc_train}")
# Out:
# the model accuracy from tarining data is 85.26666666666667

# %%
print(f"the model accuracy from testing data is {acc_test}")
# Out:
# the model accuracy from testing data is 84.36

# %% [markdown]
# # we got 84.36 accuracy from our testing data
